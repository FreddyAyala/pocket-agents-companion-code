# %%
# Out:
# 🐍 Python executable: /Users/freddyayala/Documents/GitHub/slm-ebook/.venv/bin/python
# 📦 Python path: /Users/freddyayala/.pyenv/versions/3.11.9/lib/python311.zip
# ✅ Running in virtual environment
# ✅ PyTorch version: 2.8.0
# ✅ NumPy version: 2.3.3
# ✅ Matplotlib version: 3.10.7
# ✅ SciPy version: 1.16.2

# %%
# Out:
# 🔧 Chapter 5: Pruning, Sparsity, and Distillation Demo
# ...
# PyTorch version: 2.8.0
# CUDA available: False
# ✅ All imports successful!

# %%
# Out:
# 🏗️ Model Architecture:
#    Total parameters: 23,594
#    Model size: 92.16 KB
#    Input shape: torch.Size([1, 100])
#    Output shape: torch.Size([1, 10])
# ✅ Model created and tested successfully!

# %%
# Out:
# ✂️ Magnitude-Based Pruning Results
# ...
# Pruning  10%: Sparsity   0.0%, Zero params: 0/23,594, Time: 0.09ms
# Pruning  20%: Sparsity   0.0%, Zero params: 0/23,594, Time: 0.07ms
# Pruning  30%: Sparsity   0.0%, Zero params: 0/23,594, Time: 0.07ms
# Pruning  50%: Sparsity   0.0%, Zero params: 0/23,594, Time: 0.06ms
# Pruning  70%: Sparsity   0.0%, Zero params: 0/23,594, Time: 0.06ms
# Pruning  90%: Sparsity   0.0%, Zero params: 0/23,594, Time: 0.06ms
#
# ✅ Magnitude-based pruning completed!

# %%
# Out:
# 📊 Key Insights:
#    • 90% pruning achieves 0.0% sparsity
#    • Speed improvement: 1.7x faster
#    • Zero parameters: 0 out of 23,594
#    • Inference time reduced from 0.09ms to 0.06ms

# %%
# Out:
# 👨‍🏫 Teacher Model:
#    Parameters: 67,658
#    Size: 264.29 KB
#
# 🎓 Student Model:
#    Parameters: 8,874
#    Size: 34.66 KB
#
# 📊 Compression Ratio: 7.6x smaller
#    Size reduction: 86.9%

# %%
# Out:
# 🎯 Knowledge Distillation Simulation
# ...
# Epoch  0: Loss = 0.0111
# Epoch  2: Loss = 0.0088
# Epoch  4: Loss = 0.0071
# Epoch  6: Loss = 0.0058
# Epoch  8: Loss = 0.0047
#
# ✅ Training completed!
#    Final loss: 0.0043
#    Loss reduction: 61.6%

# %%
# Out:
# 🌍 Real-World Deployment Analysis
# ...
# 📱 Model Size Comparison:
#    Original (Teacher): 0.26 MB
#    Student (Distilled): 0.03 MB
#    Pruned (90%): 0.03 MB
#
# 🚀 Deployment Feasibility:
# Mobile (4GB RAM):
#   Original: 4761 models
#   Student: 36299 models
#   Pruned: 47610 models
#
# Desktop (16GB RAM):
#   Original: 19044 models
#   Student: 145198 models
#   Pruned: 190441 models
#
# Server (64GB RAM):
#   Original: 76176 models
#   Student: 580793 models
#   Pruned: 761766 models
#
# ⚡ Performance Benefits:
#   • Pruning: 2-5x faster inference
#   • Distillation: 3-10x smaller model
#   • Combined: 5-20x improvement
#
# 🎯 Quality Trade-offs:
#   • Pruning: 1-5% accuracy loss
#   • Distillation: 2-8% accuracy loss
#   • Combined: 3-10% accuracy loss
